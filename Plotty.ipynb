# %% [markdown]
# <a href="https://colab.research.google.com/github/Neeschal1/Plotty/blob/main/Plotty.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy
# !pip install pandas
# !pip install matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("/content/drive/MyDrive/Matplotlib/readme.csv")

df.head()
# Out:
#    Student  Gender Degree             College  Hours_Studied  Exam_Score
# 0    Alice  Female    BSc     Sunrise College            2.0          55
# 1      Bob    Male    BSc   Riverside College            3.0          60
# 2  Charlie    Male   BCom     Sunrise College            1.5          50
# 3    David    Male    BSc  Greenfield College            4.0          70
# 4      Eva  Female   BCom   Riverside College            3.5          65

# %% [markdown]
# ## Plotting data making a list

# %%
studied_hours = [df["Hours_Studied"]]
exam_score = [df["Exam_Score"]]

plt.plot(studied_hours, exam_score, marker="o")
plt.xlabel("\n Hours Studied")
plt.ylabel("Marks Scored in Exams \n")
plt.plot(studied_hours, exam_score)
plt.show()

# %% [markdown]
# ## Plotting the data without list

# %%
studied_hours = df["Hours_Studied"].head()
exam_score = df["Exam_Score"].head()

plt.plot(studied_hours, exam_score, marker="o", linestyle=":")
plt.xlabel("\n Hours Studied")
plt.ylabel("Marks Scored in Exams \n")
plt.plot(studied_hours, exam_score)
plt.show()

# %% [markdown]
# ## Other properties of plotting

# %%
plt.plot(
    studied_hours, #x-axis
    exam_score, # y-axis
    marker="o", # marker type
    markerfacecolor = 'black', # center color of circular marker
    markeredgecolor = "red", # border/edge color of circular marker
    linestyle = "-", # style of line created
    linewidth = 2
)
plt.xlabel("\n Hours Studied", fontsize = 20, fontweight = "bold", color = "purple") # css property
plt.ylabel("Marks Scored in Exams \n", fontsize = 10, fontweight = "semibold", color = "green") # css property
plt.xticks(fontsize=10, rotation=15) # applicable for the elements of x-axis
plt.yticks(fontsize=10, rotation=-15) # applicable for the elements of x-axis
plt.grid(True, linestyle=":") #shows grid
plt.show()

# %% [markdown]
# ## Figure sizes

# %%
plt.figure(figsize=(13, 10))
plt.title("Relationship in between numbers of hours studied versus marks scored in exams: \n\n\n", fontsize=24, fontweight="bold", color = "green")
plt.plot(
    studied_hours,
    exam_score,
    marker = "o",
    linestyle = ":",
    markeredgecolor = "green",
    markerfacecolor = "orange",
    linewidth = 2,
    label="Exam Score"
)
plt.xlabel("\n\n STUDIED HOURS", fontsize = 20, color="red", fontweight="bold")
plt.ylabel("MARKS SCORED \n\n", fontsize = 15, color="blue", fontweight="semibold")
plt.xticks(fontsize = 10, rotation = 10)
plt.yticks(fontsize = 10, rotation = -10)
plt.legend()
plt.grid(True)
plt.show()
